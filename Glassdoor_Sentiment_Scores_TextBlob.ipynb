# %%
import pandas as pd
# !pip install textblob
from textblob import TextBlob
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/Amazon Externship/glassdoor_cleaned_text.csv')
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.12/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.12/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (8.3.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (4.67.3)

# %%
df
# Out:
#      review_id               rating_date  count_helpful  count_unhelpful  \
# 0            1  2025-06-03T00:00:00.000Z              0                0
# 1            2  2025-05-29T00:00:00.000Z              0                0
# 2            3  2025-05-28T00:00:00.000Z              0                0
# 3            4  2025-05-26T00:00:00.000Z              0                0
# 4            5  2025-05-23T00:00:00.000Z              0                0
# ..         ...                       ...            ...              ...
# 134        136  2023-03-26T00:00:00.000Z              0                0
# 135        137  2023-03-28T00:00:00.000Z              0                0
# 136        138  2023-03-30T00:00:00.000Z              0                0
# 137        139  2023-03-31T00:00:00.000Z              0                0
# 138        140  2023-04-03T00:00:00.000Z              0                0
#
#      employee_length employee_status                       employee_type  \
# 0                0.0         REGULAR                    Current employee
# 1                1.0        CONTRACT  Current employee, less than 1 year
# 2                1.0         REGULAR  Current employee, less than 1 year
# 3                2.0       PART_TIME                   Current employees
# 4                0.0         REGULAR                    Current employee
# ..               ...             ...                                 ...
# 134              NaN         REGULAR                     Former employee
# 135              5.0         REGULAR                     Former employee
# 136              NaN         REGULAR                     Former employee
# 137              NaN         REGULAR  Current employee, less than 1 year
# 138              3.0         REGULAR                     Former employee
#
#      flag_covid  flag_featured flags_business_outlook  ...  \
# 0         False          False                    NaN  ...
# 1         False          False               POSITIVE  ...
# 2         False          False               POSITIVE  ...
# 3         False          False               POSITIVE  ...
# 4         False          False                    NaN  ...
# ..          ...            ...                    ...  ...
# 134       False          False                NEUTRAL  ...
# 135       False          False               POSITIVE  ...
# 136       False          False                NEUTRAL  ...
# 137       False          False                NEUTRAL  ...
# 138       False          False               NEGATIVE  ...
#
#                                     employee_job_title  \
# 0                      Warehouse Fulfillment Associate
# 1                                  Warehouse Associate
# 2                                  Warehouse Associate
# 3                                             Employee
# 4                                Fulfillment Associate
# ..                                                 ...
# 134  Stower, picker, packer, waterspider, problem s...
# 135                                       Order picker
# 136                                Warehouse Associate
# 137                             Fc associate i, direct
# 138                                               Fc-1
#
#                            advice_to_management  \
# 0                            don’t micro manage
# 1    Remove all attitude manager from warehouse
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 134                                         NaN
# 135            More attention to the individual
# 136                                         NaN
# 137                                         NaN
# 138        Treat people fairly and with respect
#
#                                            review_pros  \
# 0    not interactive \ncan leave or take off whenev...
# 1                        good and easy work enviorment
# 2                            help to grow , good pay ,
# 3                      Plenty of work\nMeet new people
# 4    Good Holiday pay \nAdditional benefits for per...
# ..                                                 ...
# 134  -Your in control of your time (PTO)-(UPT) -Fle...
# 135           If you do your job they leave you alone.
# 136          Pay Long weekends (4 days on, 3 days off)
# 137            4 days a week, great overtime pay rates
# 138                        There are zero, zilch, None
#
#                                            review_cons  \
# 0        inhumane \ndraining physically &amp; mentally
# 1    Sticks rules and completing targets any how, o...
# 2    limited opportunities for advancement,No clear...
# 3                   Tough on the body\nLabor intensive
# 4              Not hiring permanent employees directly
# ..                                                 ...
# 134  -Management (Department Varies) -Favoritism -L...
# 135                       You are nothing but a number
# 136                          Long hours (10 hour days)
# 137              Long hours, night shift, routine work
# 138               Everything. This place sucks to work
#
#      rating_compensation_benefits  rating_senior_leadership  \
# 0                             0.0                       0.0
# 1                             5.0                       3.0
# 2                             5.0                       5.0
# 3                             2.0                       2.0
# 4                             0.0                       0.0
# ..                            ...                       ...
# 134                           5.0                       2.0
# 135                           3.0                       2.0
# 136                           NaN                       NaN
# 137                           5.0                       4.0
# 138                           1.0                       1.0
#
#     rating_career_opportunities  \
# 0                           0.0
# 1                           5.0
# 2                           5.0
# 3                           3.0
# 4                           0.0
# ..                          ...
# 134                         3.0
# 135                         2.0
# 136                         NaN
# 137                         4.0
# 138                         1.0
#
#                                    review_pros_cleaned  \
# 0    interactive leave take whenever long time easy...
# 1                            good easy work enviorment
# 2                                   help grow good pay
# 3                          plenty work meet new people
# 4    good holiday pay additional benefits permanent...
# ..                                                 ...
# 134  control time ptoupt flexibility good associate...
# 135                                    job leave alone
# 136                    pay long weekends 4 days 3 days
# 137               4 days week great overtime pay rates
# 138                                    zero zilch none
#
#                                    review_cons_cleaned      summary_cleaned
# 0            inhumane draining physically amp mentally               amazon
# 1    sticks rules completing targets otherwise get ...                 good
# 2    limited opportunities advancementno clear path...      good experience
# 3                           tough body labor intensive                 dhdh
# 4                  hiring permanent employees directly        good pay rate
# ..                                                 ...                  ...
# 134  management department varies favoritism lack l...         cash cow job
# 135                                     nothing number     good attitude ok
# 136                            long hours 10 hour days  good pay long hours
# 137                long hours night shift routine work     great place work
# 138                        everything place sucks work  terrible place work
#
# [139 rows x 28 columns]

# %%
df['sentiment_polarity'] = df['summary_cleaned'].apply(lambda x: TextBlob(x).sentiment.polarity)
df['sentiment_subjectivity'] = df['summary_cleaned'].apply(lambda x: TextBlob(x).sentiment.subjectivity)

# %%
def label_sentiment(score):
    if score > 0.1:
        return 'positive'
    elif score < -0.1:
        return 'negative'
    else:
        return 'neutral'

df['sentiment_label'] = df['sentiment_polarity'].apply(label_sentiment)

# %%
df['sentiment_label'].value_counts().plot(kind='bar', title="Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()

# %%
df['sentiment_label'].value_counts().plot(
    kind='pie',
    autopct='%1.0f%%',
    title="Sentiment Breakdown"
)
plt.ylabel('')
plt.show()

# %%
df.to_csv('glassdoor_sentiment.csv', index=False)

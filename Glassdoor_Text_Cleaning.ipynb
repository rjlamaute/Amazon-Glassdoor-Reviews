# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Amazon Externship/glassdoor_cleaned.csv')

# %%
import nltk
import string
from nltk.corpus import stopwords
nltk.download('stopwords')

def clean_text(text):
    if pd.isnull(text):
        return ""
    tokens = text.lower().translate(str.maketrans('', '', string.punctuation)).split()
    return ' '.join([word for word in tokens if word not in stopwords.words('english')])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(df.head())
# Out:
#    review_id               rating_date  count_helpful  count_unhelpful  \
# 0          1  2025-06-03T00:00:00.000Z              0                0
# 1          2  2025-05-29T00:00:00.000Z              0                0
# 2          3  2025-05-28T00:00:00.000Z              0                0
# 3          4  2025-05-26T00:00:00.000Z              0                0
# 4          5  2025-05-23T00:00:00.000Z              0                0
#
#    employee_length employee_status                       employee_type  \
# 0              0.0         REGULAR                    Current employee
# 1              1.0        CONTRACT  Current employee, less than 1 year
# 2              1.0         REGULAR  Current employee, less than 1 year
# 3              2.0       PART_TIME                   Current employees
# 4              0.0         REGULAR                    Current employee
#
#    flag_covid  flag_featured flags_business_outlook  ... rating_work_life  \
# 0       False          False                    NaN  ...              0.0
# 1       False          False               POSITIVE  ...              3.0
# 2       False          False               POSITIVE  ...              5.0
# 3       False          False               POSITIVE  ...              2.0
# 4       False          False                    NaN  ...              0.0
#
#            summary  employee_location               employee_job_title  \
# 0           Amazon       Richmond, VA  Warehouse Fulfillment Associate
# 1             Good       Brampton, ON              Warehouse Associate
# 2  Good experience         Bolton, ON              Warehouse Associate
# 3             Dhdh     Swedesboro, NJ                         Employee
# 4    Good Pay rate         Whitby, ON            Fulfillment Associate
#
#                          advice_to_management  \
# 0                          don’t micro manage
# 1  Remove all attitude manager from warehouse
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                                          review_pros  \
# 0  not interactive \ncan leave or take off whenev...
# 1                      good and easy work enviorment
# 2                          help to grow , good pay ,
# 3                    Plenty of work\nMeet new people
# 4  Good Holiday pay \nAdditional benefits for per...
#
#                                          review_cons  \
# 0      inhumane \ndraining physically &amp; mentally
# 1  Sticks rules and completing targets any how, o...
# 2  limited opportunities for advancement,No clear...
# 3                 Tough on the body\nLabor intensive
# 4            Not hiring permanent employees directly
#
#   rating_compensation_benefits rating_senior_leadership  \
# 0                          0.0                      0.0
# 1                          5.0                      3.0
# 2                          5.0                      5.0
# 3                          2.0                      2.0
# 4                          0.0                      0.0
#
#   rating_career_opportunities
# 0                         0.0
# 1                         5.0
# 2                         5.0
# 3                         3.0
# 4                         0.0
#
# [5 rows x 25 columns]

# %%
df['review_pros_cleaned'] = df['review_pros'].apply(clean_text)

# %%
df['review_cons_cleaned'] = df['review_cons'].apply(clean_text)

# %%
df['advice_to_management_cleaned'] = df['advice_to_management'].apply(clean_text)

# %%
df['summary_cleaned'] = df['summary'].apply(clean_text)

# %%
df = df.drop(columns=['advice_to_management_cleaned'])
df.to_csv('/content/drive/MyDrive/Amazon Externship/glassdoor_cleaned_text.csv', index=False)
